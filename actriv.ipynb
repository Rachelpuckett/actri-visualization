# %% [markdown]
# # actri-visualization

# %%
import ssl
import numpy as np
import matplotlib
import pandas as pd

# %%
##pd settings
pd.set_option('display.max_columns', 100)
##opening databases
land = pd.read_csv("tri_land.csv")
air = pd.read_csv("tri_air.csv")
ug = pd.read_csv("tri_underground1.csv")
water = pd.read_csv("tri_water.csv")

##displaying first 5 rows of each database
land.head(5)
#ug.head(5)
#water.head(5)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (13,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    TRI_FACILITY_ID   DOC_CTRL_NUM                   FACILITY_NAME  \
# 0  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
# 1  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
# 2  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
# 3  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
# 4  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
#
#    STREET_ADDRESS CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE STATE_ABBR  \
# 0  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 1  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 2  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 3  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 4  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
#
#    ZIP_CODE  REGION  FAC_CLOSED_IND ASGN_FEDERAL_IND ASGN_AGENCY  \
# 0     15025       3               0                C         NaN
# 1     15025       3               0                C         NaN
# 2     15025       3               0                C         NaN
# 3     15025       3               0                C         NaN
# 4     15025       3               0                C         NaN
#
#   PARENT_CO_DB_NUM PARENT_CO_NAME STANDARDIZED_PARENT_COMPANY  \
# 0        196991582    KOPPERS INC                 KOPPERS INC
# 1        196991582    KOPPERS INC                 KOPPERS INC
# 2        196991582    KOPPERS INC                 KOPPERS INC
# 3        196991582    KOPPERS INC                 KOPPERS INC
# 4        196991582    KOPPERS INC                 KOPPERS INC
#
#    EPA_REGISTRY_ID  TRADE_SECRET_IND  REPORTING_YEAR ELEMENTAL_METAL_INCLUDED  \
# 0     1.100003e+11                 0            1988                 106-44-5
# 1     1.100003e+11                 0            1988                 106-44-5
# 2     1.100003e+11                 0            1988                 106-44-5
# 3     1.100003e+11                 0            1988                 106-44-5
# 4     1.100003e+11                 0            1988                 106-44-5
#
#   CAS_NUM CHEM_NAME LIST_3350 CARCINOGEN CLEAN_AIR PRIMARY_SIC_CODE SIC_CODES  \
# 0     NaN  P-CRESOL         N          N         Y             2865      2865
# 1     NaN  P-CRESOL         N          N         Y             2865      2865
# 2     NaN  P-CRESOL         N          N         Y             2865      2865
# 3     NaN  P-CRESOL         N          N         Y             2865      2865
# 4     NaN  P-CRESOL         N          N         Y             2865      2865
#
#    PRIMARY_NAICS_CODE  NAICS_CODES  INDUSTRY_CODE ENVIRONMENTAL_MEDIUM  \
# 0              325192     325192.0            325            LAND TREA
# 1              325192     325192.0            325            LANDF8795
# 2              325192     325192.0            325             OTH DISP
# 3              325192     325192.0            325            OTH LANDF
# 4              325192     325192.0            325               RCRA C
#
#   RELEASE_RANGE_CODE  TOTAL_RELEASE  REL_EST_AMT  RELEASE_NA  \
# 0                NaN            NaN          0.0           1
# 1                NaN            NaN          0.0           1
# 2                NaN            NaN          0.0           1
# 3                NaN            NaN          0.0           0
# 4                NaN            NaN          0.0           0
#
#   RELEASE_BASIS_EST_CODE   SRS_ID
# 0                    NaN  23606.0
# 1                    NaN  23606.0
# 2                    NaN  23606.0
# 3                    NaN  23606.0
# 4                    NaN  23606.0

# %%
air.head(5)
# Out:
#    TRI_FACILITY_ID   DOC_CTRL_NUM                         FACILITY_NAME  \
# 0  15025RSTCH400ST  1388025294164        KOPPERS INC CLAIRTON TAR PLANT
# 1  15025RSTCH400ST  1388025294164        KOPPERS INC CLAIRTON TAR PLANT
# 2  15049WTSNS616HI  1317215995768      WATSON STANDARD CO HARWICK PLANT
# 3  15049WTSNS616HI  1317215995768      WATSON STANDARD CO HARWICK PLANT
# 4  15144PPGND125CO  1390045547217  PPG INDUSTRIESINC-SPRINGDALE COMPLEX
#
#    STREET_ADDRESS   CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE STATE_ABBR  \
# 0  300 N STATE ST    CLAIRTON   ALLEGHENY                   42003         PA
# 1  300 N STATE ST    CLAIRTON   ALLEGHENY                   42003         PA
# 2     616 HITE RD     HARWICK   ALLEGHENY                   42003         PA
# 3     616 HITE RD     HARWICK   ALLEGHENY                   42003         PA
# 4   125 COLFAX ST  SPRINGDALE   ALLEGHENY                   42003         PA
#
#    ZIP_CODE  REGION  FAC_CLOSED_IND ASGN_FEDERAL_IND ASGN_AGENCY  \
# 0     15025       3               0                C         NaN
# 1     15025       3               0                C         NaN
# 2     15049       3               0                C         NaN
# 3     15049       3               0                C         NaN
# 4     15144       3               0                C         NaN
#
#   PARENT_CO_DB_NUM         PARENT_CO_NAME STANDARDIZED_PARENT_COMPANY  \
# 0        196991582            KOPPERS INC                 KOPPERS INC
# 1        196991582            KOPPERS INC                 KOPPERS INC
# 2        834950552  WATSON INDUSTRIES INC       WATSON INDUSTRIES INC
# 3        834950552  WATSON INDUSTRIES INC       WATSON INDUSTRIES INC
# 4        001344803     PPG INDUSTRIES INC          PPG INDUSTRIES INC
#
#    EPA_REGISTRY_ID  TRADE_SECRET_IND  REPORTING_YEAR CAS_NUM  \
# 0     1.100003e+11                 0            1988     NaN
# 1     1.100003e+11                 0            1988     NaN
# 2     1.100078e+11                 0            2017     NaN
# 3     1.100078e+11                 0            2017     NaN
# 4     1.100003e+11                 0            1990     NaN
#
#   ELEMENTAL_METAL_INCLUDED         CHEM_NAME LIST_3350 CARCINOGEN CLEAN_AIR  \
# 0                 P-CRESOL          P-CRESOL         N          N         Y
# 1                 P-CRESOL          P-CRESOL         N          N         Y
# 2              NAPHTHALENE       NAPHTHALENE         N          Y         Y
# 3              NAPHTHALENE       NAPHTHALENE         N          Y         Y
# 4         BARIUM COMPOUNDS  BARIUM COMPOUNDS         N          N         N
#
#   PRIMARY_SIC_CODE   SIC_CODES  PRIMARY_NAICS_CODE  NAICS_CODES  \
# 0             2865        2865              325192     325192.0
# 1             2865        2865              325192     325192.0
# 2              NaN         NaN              325510     325510.0
# 3              NaN         NaN              325510     325510.0
# 4             2851  28512821NA              325510     325510.0
#
#    INDUSTRY_CODE ENVIRONMENTAL_MEDIUM  RELEASE_RANGE_CODE  TOTAL_RELEASE  \
# 0            325              AIR FUG                 NaN           21.0
# 1            325            AIR STACK                 NaN          110.0
# 2            325              AIR FUG                 NaN           62.0
# 3            325            AIR STACK                 NaN            NaN
# 4            325              AIR FUG                 NaN            0.0
#
#    REL_EST_AMT  RELEASE_NA RELEASE_BASIS_EST_CODE    SRS_ID
# 0         21.0           0                      O   23606.0
# 1        110.0           0                      O   23606.0
# 2         62.0           0                      C   13326.0
# 3          0.0           1                    NaN   13326.0
# 4          0.0           0                      O  649426.0

# %%
ug.head(5)
# Out:
#    TRI_FACILITY_ID   DOC_CTRL_NUM                     FACILITY_NAME  \
# 0  15025RSTCH400ST  1388025294164    KOPPERS INC CLAIRTON TAR PLANT
# 1  15025RSTCH400ST  1388025294164    KOPPERS INC CLAIRTON TAR PLANT
# 2  15025RSTCH400ST  1388025294164    KOPPERS INC CLAIRTON TAR PLANT
# 3  15049WTSNS616HI  1317215995768  WATSON STANDARD CO HARWICK PLANT
# 4  15049WTSNS616HI  1317215995768  WATSON STANDARD CO HARWICK PLANT
#
#    STREET_ADDRESS CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE STATE_ABBR  \
# 0  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 1  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 2  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 3     616 HITE RD   HARWICK   ALLEGHENY                   42003         PA
# 4     616 HITE RD   HARWICK   ALLEGHENY                   42003         PA
#
#    ZIP_CODE  REGION  FAC_CLOSED_IND ASGN_FEDERAL_IND ASGN_AGENCY  \
# 0     15025       3               0                C         NaN
# 1     15025       3               0                C         NaN
# 2     15025       3               0                C         NaN
# 3     15049       3               0                C         NaN
# 4     15049       3               0                C         NaN
#
#   PARENT_CO_DB_NUM         PARENT_CO_NAME STANDARDIZED_PARENT_COMPANY  \
# 0        196991582            KOPPERS INC                 KOPPERS INC
# 1        196991582            KOPPERS INC                 KOPPERS INC
# 2        196991582            KOPPERS INC                 KOPPERS INC
# 3        834950552  WATSON INDUSTRIES INC       WATSON INDUSTRIES INC
# 4        834950552  WATSON INDUSTRIES INC       WATSON INDUSTRIES INC
#
#    EPA_REGISTRY_ID  TRADE_SECRET_IND  REPORTING_YEAR   CAS_NUM  \
# 0     1.100003e+11                 0            1988  106-44-5
# 1     1.100003e+11                 0            1988  106-44-5
# 2     1.100003e+11                 0            1988  106-44-5
# 3     1.100078e+11                 0            2017   91-20-3
# 4     1.100078e+11                 0            2017   91-20-3
#
#   ELEMENTAL_METAL_INCLUDED    CHEM_NAME LIST_3350 CARCINOGEN CLEAN_AIR  \
# 0                      NaN     P-CRESOL         N          N         Y
# 1                      NaN     P-CRESOL         N          N         Y
# 2                      NaN     P-CRESOL         N          N         Y
# 3                      NaN  NAPHTHALENE         N          Y         Y
# 4                      NaN  NAPHTHALENE         N          Y         Y
#
#   PRIMARY_SIC_CODE SIC_CODES  PRIMARY_NAICS_CODE  NAICS_CODES  INDUSTRY_CODE  \
# 0             2865      2865              325192     325192.0            325
# 1             2865      2865              325192     325192.0            325
# 2             2865      2865              325192     325192.0            325
# 3              NaN       NaN              325510     325510.0            325
# 4              NaN       NaN              325510     325510.0            325
#
#   ENVIRONMENTAL_MEDIUM RELEASE_RANGE_CODE  TOTAL_RELEASE  REL_EST_AMT  \
# 0              UNINJ I                NaN            NaN            0
# 1            UNINJ IIV                NaN            NaN            0
# 2            UNINJ8795                NaN            NaN            0
# 3              UNINJ I                NaN            NaN            0
# 4            UNINJ IIV                NaN            NaN            0
#
#    RELEASE_NA RELEASE_BASIS_EST_CODE   SRS_ID
# 0           0                    NaN  23606.0
# 1           0                    NaN  23606.0
# 2           1                    NaN  23606.0
# 3           1                    NaN  13326.0
# 4           1                    NaN  13326.0

# %%
water.head(5)
# Out:
#    TRI_FACILITY_ID   DOC_CTRL_NUM                         FACILITY_NAME  \
# 0  15025RSTCH400ST  1388025294164        KOPPERS INC CLAIRTON TAR PLANT
# 1  15049WTSNS616HI  1317215995768      WATSON STANDARD CO HARWICK PLANT
# 2  15144PPGND125CO  1390045547217  PPG INDUSTRIESINC-SPRINGDALE COMPLEX
# 3  15144PPGND125CO  1390045547217  PPG INDUSTRIESINC-SPRINGDALE COMPLEX
# 4  15025RSTCH400ST  1396100163118        KOPPERS INC CLAIRTON TAR PLANT
#
#    STREET_ADDRESS   CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE STATE_ABBR  \
# 0  300 N STATE ST    CLAIRTON   ALLEGHENY                   42003         PA
# 1     616 HITE RD     HARWICK   ALLEGHENY                   42003         PA
# 2   125 COLFAX ST  SPRINGDALE   ALLEGHENY                   42003         PA
# 3   125 COLFAX ST  SPRINGDALE   ALLEGHENY                   42003         PA
# 4  300 N STATE ST    CLAIRTON   ALLEGHENY                   42003         PA
#
#    ZIP_CODE  REGION  FAC_CLOSED_IND ASGN_FEDERAL_IND ASGN_AGENCY  \
# 0     15025       3               0                C         NaN
# 1     15049       3               0                C         NaN
# 2     15144       3               0                C         NaN
# 3     15144       3               0                C         NaN
# 4     15025       3               0                C         NaN
#
#   PARENT_CO_DB_NUM         PARENT_CO_NAME STANDARDIZED_PARENT_COMPANY  \
# 0        196991582            KOPPERS INC                 KOPPERS INC
# 1        834950552  WATSON INDUSTRIES INC       WATSON INDUSTRIES INC
# 2        001344803     PPG INDUSTRIES INC          PPG INDUSTRIES INC
# 3        001344803     PPG INDUSTRIES INC          PPG INDUSTRIES INC
# 4        196991582            KOPPERS INC                 KOPPERS INC
#
#    EPA_REGISTRY_ID  TRADE_SECRET_IND  REPORTING_YEAR   CAS_NUM  \
# 0     1.100003e+11                 0            1988  106-44-5
# 1     1.100078e+11                 0            2017   91-20-3
# 2     1.100003e+11                 0            1990      N040
# 3     1.100003e+11                 0            1990      N040
# 4     1.100003e+11                 0            1996  120-12-7
#
#   ELEMENTAL_METAL_INCLUDED         CHEM_NAME LIST_3350 CARCINOGEN CLEAN_AIR  \
# 0                      NaN          P-CRESOL         N          N         Y
# 1                      NaN       NAPHTHALENE         N          Y         Y
# 2                      NaN  BARIUM COMPOUNDS         N          N         N
# 3                      NaN  BARIUM COMPOUNDS         N          N         N
# 4                      NaN        ANTHRACENE         N          N         N
#
#   PRIMARY_SIC_CODE   SIC_CODES  PRIMARY_NAICS_CODE  NAICS_CODES  \
# 0             2865        2865              325192     325192.0
# 1              NaN         NaN              325510     325510.0
# 2             2851  28512821NA              325510     325510.0
# 3             2851  28512821NA              325510     325510.0
# 4             2865      2865NA              325110     325110.0
#
#    INDUSTRY_CODE ENVIRONMENTAL_MEDIUM  RELEASE_RANGE_CODE  TOTAL_RELEASE  \
# 0            325                WATER                 NaN            0.0
# 1            325                WATER                 NaN            NaN
# 2            325                WATER                 NaN            0.0
# 3            325                WATER                 NaN            NaN
# 4            325                WATER                 NaN            NaN
#
#    REL_EST_AMT  RELEASE_NA RELEASE_BASIS_EST_CODE  WATER_SEQUENCE_NUM  \
# 0          0.0           0                      O                   1
# 1          0.0           1                    NaN                   1
# 2          0.0           0                      O                   1
# 3          0.0           0                    NaN                   2
# 4          0.0           0                    NaN                   1
#
#        STREAM_NAME  STORM_WATER_NA  STORM_WATER_PERCENT    SRS_ID  REACH_CODE
# 0     PETERS CREEK               0                  NaN   23606.0         NaN
# 1              NaN               0                  NaN   13326.0         NaN
# 2  ALLEGHENY RIVER               1                  NaN  649426.0         NaN
# 3              NaN               0                  NaN  649426.0         NaN
# 4              NaN               0                  NaN   31013.0         NaN

# %%
### Let's try cleaning this up a bit. 
#land.drop(columns=['TRI_FACILITY_ID', 'DOC_CTRL_NUM', 'STATE_COUNTY_FIPS_CODE', 'STATE_ABBR', 'REGION', 'PRIMARY_NAICS_CODE', 'NAICS_CODES', "INDUSTRY_CODE"])
land = land.drop(columns=['TRI_FACILITY_ID','DOC_CTRL_NUM', 'STATE_COUNTY_FIPS_CODE', 'STATE_ABBR', 'REGION'
                   , 'FAC_CLOSED_IND', 'ASGN_FEDERAL_IND', 'ASGN_AGENCY', 'PARENT_CO_DB_NUM'
                   , 'PARENT_CO_NAME', 'EPA_REGISTRY_ID', 'TRADE_SECRET_IND', 'ELEMENTAL_METAL_INCLUDED'
                   , 'CAS_NUM', 'LIST_3350', 'PRIMARY_SIC_CODE', 'SIC_CODES', 'PRIMARY_NAICS_CODE'
                   , 'NAICS_CODES', 'INDUSTRY_CODE', 'RELEASE_RANGE_CODE', 'TOTAL_RELEASE'
                   , 'REL_EST_AMT', 'RELEASE_NA', 'RELEASE_BASIS_EST_CODE', 'SRS_ID'])

# %%
air = air.drop(columns=['TRI_FACILITY_ID','DOC_CTRL_NUM', 'STATE_COUNTY_FIPS_CODE', 'STATE_ABBR', 'REGION'
                   , 'FAC_CLOSED_IND', 'ASGN_FEDERAL_IND', 'ASGN_AGENCY', 'PARENT_CO_DB_NUM'
                   , 'PARENT_CO_NAME', 'EPA_REGISTRY_ID', 'TRADE_SECRET_IND', 'ELEMENTAL_METAL_INCLUDED'
                   , 'CAS_NUM', 'LIST_3350', 'PRIMARY_SIC_CODE', 'SIC_CODES', 'PRIMARY_NAICS_CODE'
                   , 'NAICS_CODES', 'INDUSTRY_CODE', 'RELEASE_RANGE_CODE', 'TOTAL_RELEASE'
                   , 'REL_EST_AMT', 'RELEASE_NA', 'RELEASE_BASIS_EST_CODE', 'SRS_ID'])

# %%
water = water.drop(columns=['TRI_FACILITY_ID','DOC_CTRL_NUM', 'STATE_COUNTY_FIPS_CODE', 'STATE_ABBR', 'REGION'
                   , 'FAC_CLOSED_IND', 'ASGN_FEDERAL_IND', 'ASGN_AGENCY', 'PARENT_CO_DB_NUM'
                   , 'PARENT_CO_NAME', 'EPA_REGISTRY_ID', 'TRADE_SECRET_IND', 'ELEMENTAL_METAL_INCLUDED'
                   , 'CAS_NUM', 'LIST_3350', 'PRIMARY_SIC_CODE', 'SIC_CODES', 'PRIMARY_NAICS_CODE'
                   , 'NAICS_CODES', 'INDUSTRY_CODE', 'RELEASE_RANGE_CODE', 'TOTAL_RELEASE'
                   , 'REL_EST_AMT', 'RELEASE_NA', 'RELEASE_BASIS_EST_CODE', 'SRS_ID', 'WATER_SEQUENCE_NUM', 'STORM_WATER_NA', 'STORM_WATER_PERCENT', 'REACH_CODE'])

# %%
ug = ug.drop(columns=['TRI_FACILITY_ID','DOC_CTRL_NUM', 'STATE_COUNTY_FIPS_CODE', 'STATE_ABBR', 'REGION'
                   , 'FAC_CLOSED_IND', 'ASGN_FEDERAL_IND', 'ASGN_AGENCY', 'PARENT_CO_DB_NUM'
                   , 'PARENT_CO_NAME', 'EPA_REGISTRY_ID', 'TRADE_SECRET_IND', 'ELEMENTAL_METAL_INCLUDED'
                   , 'CAS_NUM', 'LIST_3350', 'PRIMARY_SIC_CODE', 'SIC_CODES', 'PRIMARY_NAICS_CODE'
                   , 'NAICS_CODES', 'INDUSTRY_CODE', 'RELEASE_RANGE_CODE', 'TOTAL_RELEASE'
                   , 'REL_EST_AMT', 'RELEASE_NA', 'RELEASE_BASIS_EST_CODE', 'SRS_ID'])

# %%
##Filtering out the rows that are reported before the year 2000
air.drop(air[air['REPORTING_YEAR'] < 2000].index, inplace = True)
air.head(10)
# Out:
#                               FACILITY_NAME    STREET_ADDRESS     CITY_NAME  \
# 2          WATSON STANDARD CO HARWICK PLANT       616 HITE RD       HARWICK
# 3          WATSON STANDARD CO HARWICK PLANT       616 HITE RD       HARWICK
# 12     PPG INDUSTRIESINC-SPRINGDALE COMPLEX     125 COLFAX ST    SPRINGDALE
# 13     PPG INDUSTRIESINC-SPRINGDALE COMPLEX     125 COLFAX ST    SPRINGDALE
# 18                     PRESSURE CHEMICAL CO  3419 SMALLMAN ST    PITTSBURGH
# 19                     PRESSURE CHEMICAL CO  3419 SMALLMAN ST    PITTSBURGH
# 20    ATI FLAT ROLLED PRODUCTS HOLDINGS LLC      100 RIVER RD  BRACKENRIDGE
# 21    ATI FLAT ROLLED PRODUCTS HOLDINGS LLC      100 RIVER RD  BRACKENRIDGE
# 22  SAFETY-KLEEN SYSTEMS WEST MIFFLIN (WMP)      650 NOBLE DR  WEST MIFFLIN
# 23  SAFETY-KLEEN SYSTEMS WEST MIFFLIN (WMP)      650 NOBLE DR  WEST MIFFLIN
#
#    COUNTY_NAME  ZIP_CODE STANDARDIZED_PARENT_COMPANY  REPORTING_YEAR  \
# 2    ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 3    ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 12   ALLEGHENY     15144          PPG INDUSTRIES INC            2014
# 13   ALLEGHENY     15144          PPG INDUSTRIES INC            2014
# 18   ALLEGHENY     15201                         NaN            2019
# 19   ALLEGHENY     15201                         NaN            2019
# 20   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC            2000
# 21   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC            2000
# 22   ALLEGHENY     15122           CLEAN HARBORS INC            2010
# 23   ALLEGHENY     15122           CLEAN HARBORS INC            2010
#
#                         CHEM_NAME CARCINOGEN CLEAN_AIR ENVIRONMENTAL_MEDIUM
# 2                     NAPHTHALENE          Y         Y              AIR FUG
# 3                     NAPHTHALENE          Y         Y            AIR STACK
# 12                N-BUTYL ALCOHOL          N         N              AIR FUG
# 13                N-BUTYL ALCOHOL          N         N            AIR STACK
# 18               MALEIC ANHYDRIDE          N         Y              AIR FUG
# 19               MALEIC ANHYDRIDE          N         Y            AIR STACK
# 20            MOLYBDENUM TRIOXIDE          N         N              AIR FUG
# 21            MOLYBDENUM TRIOXIDE          N         N            AIR STACK
# 22  POLYCYCLIC AROMATIC COMPOUNDS          Y         Y              AIR FUG
# 23  POLYCYCLIC AROMATIC COMPOUNDS          Y         Y            AIR STACK

# %%
water.drop(water[water['REPORTING_YEAR'] < 2000].index, inplace = True)
water.head(10)
# Out:
#                                       FACILITY_NAME        STREET_ADDRESS  \
# 1                  WATSON STANDARD CO HARWICK PLANT           616 HITE RD
# 7              PPG INDUSTRIESINC-SPRINGDALE COMPLEX         125 COLFAX ST
# 11                             PRESSURE CHEMICAL CO      3419 SMALLMAN ST
# 12            ATI FLAT ROLLED PRODUCTS HOLDINGS LLC          100 RIVER RD
# 13          SAFETY-KLEEN SYSTEMS WEST MIFFLIN (WMP)          650 NOBLE DR
# 14           SEQUA COATINGS CORP PRECOAT METALS DIV        3500 WALNUT ST
# 16                                     SHENANGO INC        200 NEVILLE RD
# 17         BP PRODUCTS NA INC - CORAOPOLIS TERMINAL  3200 UNIVERSITY BLVD
# 18                              SHERWIN-WILLIAMS CO      2000 WESTHALL ST
# 20  STEEL DYNAMICS INC - TECHS DIV - GALVTECH PLANT        300 MIFFLIN RD
#
#        CITY_NAME COUNTY_NAME  ZIP_CODE STANDARDIZED_PARENT_COMPANY  \
# 1        HARWICK   ALLEGHENY     15049       WATSON INDUSTRIES INC
# 7     SPRINGDALE   ALLEGHENY     15144          PPG INDUSTRIES INC
# 11    PITTSBURGH   ALLEGHENY     15201                         NaN
# 12  BRACKENRIDGE   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC
# 13  WEST MIFFLIN   ALLEGHENY     15122           CLEAN HARBORS INC
# 14   MC KEESPORT   ALLEGHENY     15132                         NaN
# 16    PITTSBURGH   ALLEGHENY     15225               DTE ENERGY CO
# 17    CORAOPOLIS   ALLEGHENY     15108                         NaN
# 18    PITTSBURGH   ALLEGHENY     15233     THE SHERWIN-WILLIAMS CO
# 20    PITTSBURGH   ALLEGHENY     15207          STEEL DYNAMICS INC
#
#     REPORTING_YEAR                      CHEM_NAME CARCINOGEN CLEAN_AIR  \
# 1             2017                    NAPHTHALENE          Y         Y
# 7             2014                N-BUTYL ALCOHOL          N         N
# 11            2019               MALEIC ANHYDRIDE          N         Y
# 12            2000            MOLYBDENUM TRIOXIDE          N         N
# 13            2010  POLYCYCLIC AROMATIC COMPOUNDS          Y         Y
# 14            2008                 LEAD COMPOUNDS          N         Y
# 16            2015         XYLENE (MIXED ISOMERS)          N         Y
# 17            2000                        BENZENE          Y         Y
# 18            2007         XYLENE (MIXED ISOMERS)          N         Y
# 20            2005                 LEAD COMPOUNDS          N         Y
#
#    ENVIRONMENTAL_MEDIUM STREAM_NAME
# 1                 WATER         NaN
# 7                 WATER         NaN
# 11                WATER         NaN
# 12                WATER         NaN
# 13                WATER         NaN
# 14                WATER         NaN
# 16                WATER         NaN
# 17                WATER  OHIO RIVER
# 18                WATER         NaN
# 20                WATER         NaN

# %%
land.drop(land[land['REPORTING_YEAR'] < 2000].index, inplace = True)
land.head(10)
# Out:
#                            FACILITY_NAME STREET_ADDRESS   CITY_NAME  \
# 6       WATSON STANDARD CO HARWICK PLANT    616 HITE RD     HARWICK
# 7       WATSON STANDARD CO HARWICK PLANT    616 HITE RD     HARWICK
# 8       WATSON STANDARD CO HARWICK PLANT    616 HITE RD     HARWICK
# 9       WATSON STANDARD CO HARWICK PLANT    616 HITE RD     HARWICK
# 10      WATSON STANDARD CO HARWICK PLANT    616 HITE RD     HARWICK
# 11      WATSON STANDARD CO HARWICK PLANT    616 HITE RD     HARWICK
# 34  PPG INDUSTRIESINC-SPRINGDALE COMPLEX  125 COLFAX ST  SPRINGDALE
# 35  PPG INDUSTRIESINC-SPRINGDALE COMPLEX  125 COLFAX ST  SPRINGDALE
# 36  PPG INDUSTRIESINC-SPRINGDALE COMPLEX  125 COLFAX ST  SPRINGDALE
# 37  PPG INDUSTRIESINC-SPRINGDALE COMPLEX  125 COLFAX ST  SPRINGDALE
#
#    COUNTY_NAME  ZIP_CODE STANDARDIZED_PARENT_COMPANY  REPORTING_YEAR  \
# 6    ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 7    ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 8    ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 9    ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 10   ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 11   ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 34   ALLEGHENY     15144          PPG INDUSTRIES INC            2014
# 35   ALLEGHENY     15144          PPG INDUSTRIES INC            2014
# 36   ALLEGHENY     15144          PPG INDUSTRIES INC            2014
# 37   ALLEGHENY     15144          PPG INDUSTRIES INC            2014
#
#           CHEM_NAME CARCINOGEN CLEAN_AIR ENVIRONMENTAL_MEDIUM
# 6       NAPHTHALENE          Y         Y            LAND TREA
# 7       NAPHTHALENE          Y         Y             OTH DISP
# 8       NAPHTHALENE          Y         Y            OTH LANDF
# 9       NAPHTHALENE          Y         Y               RCRA C
# 10      NAPHTHALENE          Y         Y            SI 5.5.3A
# 11      NAPHTHALENE          Y         Y            SI 5.5.3B
# 34  N-BUTYL ALCOHOL          N         N            LAND TREA
# 35  N-BUTYL ALCOHOL          N         N             OTH DISP
# 36  N-BUTYL ALCOHOL          N         N            OTH LANDF
# 37  N-BUTYL ALCOHOL          N         N               RCRA C

# %%
ug.drop(ug[ug['REPORTING_YEAR'] < 2000].index, inplace = True)
ug.head(10)
# Out:
#                               FACILITY_NAME    STREET_ADDRESS     CITY_NAME  \
# 3          WATSON STANDARD CO HARWICK PLANT       616 HITE RD       HARWICK
# 4          WATSON STANDARD CO HARWICK PLANT       616 HITE RD       HARWICK
# 15     PPG INDUSTRIESINC-SPRINGDALE COMPLEX     125 COLFAX ST    SPRINGDALE
# 16     PPG INDUSTRIESINC-SPRINGDALE COMPLEX     125 COLFAX ST    SPRINGDALE
# 22                     PRESSURE CHEMICAL CO  3419 SMALLMAN ST    PITTSBURGH
# 23                     PRESSURE CHEMICAL CO  3419 SMALLMAN ST    PITTSBURGH
# 24    ATI FLAT ROLLED PRODUCTS HOLDINGS LLC      100 RIVER RD  BRACKENRIDGE
# 25    ATI FLAT ROLLED PRODUCTS HOLDINGS LLC      100 RIVER RD  BRACKENRIDGE
# 26  SAFETY-KLEEN SYSTEMS WEST MIFFLIN (WMP)      650 NOBLE DR  WEST MIFFLIN
# 27  SAFETY-KLEEN SYSTEMS WEST MIFFLIN (WMP)      650 NOBLE DR  WEST MIFFLIN
#
#    COUNTY_NAME  ZIP_CODE STANDARDIZED_PARENT_COMPANY  REPORTING_YEAR  \
# 3    ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 4    ALLEGHENY     15049       WATSON INDUSTRIES INC            2017
# 15   ALLEGHENY     15144          PPG INDUSTRIES INC            2014
# 16   ALLEGHENY     15144          PPG INDUSTRIES INC            2014
# 22   ALLEGHENY     15201                         NaN            2019
# 23   ALLEGHENY     15201                         NaN            2019
# 24   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC            2000
# 25   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC            2000
# 26   ALLEGHENY     15122           CLEAN HARBORS INC            2010
# 27   ALLEGHENY     15122           CLEAN HARBORS INC            2010
#
#                         CHEM_NAME CARCINOGEN CLEAN_AIR ENVIRONMENTAL_MEDIUM
# 3                     NAPHTHALENE          Y         Y              UNINJ I
# 4                     NAPHTHALENE          Y         Y            UNINJ IIV
# 15                N-BUTYL ALCOHOL          N         N              UNINJ I
# 16                N-BUTYL ALCOHOL          N         N            UNINJ IIV
# 22               MALEIC ANHYDRIDE          N         Y              UNINJ I
# 23               MALEIC ANHYDRIDE          N         Y            UNINJ IIV
# 24            MOLYBDENUM TRIOXIDE          N         N              UNINJ I
# 25            MOLYBDENUM TRIOXIDE          N         N            UNINJ IIV
# 26  POLYCYCLIC AROMATIC COMPOUNDS          Y         Y              UNINJ I
# 27  POLYCYCLIC AROMATIC COMPOUNDS          Y         Y            UNINJ IIV

# %%
##ordering the rows from oldest to newest
air.sort_values('REPORTING_YEAR')
# Out:
#                                           FACILITY_NAME  \
# 24591             ATI FLAT ROLLED PRODUCTS HOLDINGS LLC
# 7955   EXXONMOBIL LUBRICANTS & PETROLEUM SPECIALTIES CO
# 4568            EXXONMOBIL CORP NEVILLE ISLAND TERMINAL
# 4569            EXXONMOBIL CORP NEVILLE ISLAND TERMINAL
# 22214          UNIVAR SOLUTIONS USA INC - BUNOLA BRANCH
# ...                                                 ...
# 6462                                  THE LUBRIZOL CORP
# 6431                            INEOS COMPOSITES US LLC
# 6430                            INEOS COMPOSITES US LLC
# 12824           SAFETY-KLEEN SYSTEMS WEST MIFFLIN (WMP)
# 23863             ATI FLAT ROLLED PRODUCTS HOLDINGS LLC
#
#                                           STREET_ADDRESS     CITY_NAME  \
# 24591                                       100 RIVER RD  BRACKENRIDGE
# 7955                  1031 MIDDLESEX ST BAKERSTOWN PLANT    BAKERSTOWN
# 4568                                     2760 NEVILLE RD    PITTSBURGH
# 4569                                     2760 NEVILLE RD    PITTSBURGH
# 22214                                328 BUNOLA RIVER RD        BUNOLA
# ...                                                  ...           ...
# 6462   100 LEETSDALE INDUSTRIAL DR - BUILDINGS 72, 76...     LEETSDALE
# 6431                                     2650 NEVILLE RD    PITTSBURGH
# 6430                                     2650 NEVILLE RD    PITTSBURGH
# 12824                                       650 NOBLE DR  WEST MIFFLIN
# 23863                                       100 RIVER RD  BRACKENRIDGE
#
#       COUNTY_NAME  ZIP_CODE STANDARDIZED_PARENT_COMPANY  REPORTING_YEAR  \
# 24591   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC            2000
# 7955    ALLEGHENY     15007                         NaN            2000
# 4568    ALLEGHENY     15225                         NaN            2000
# 4569    ALLEGHENY     15225                         NaN            2000
# 22214   ALLEGHENY     15020                         NaN            2000
# ...           ...       ...                         ...             ...
# 6462    ALLEGHENY     15056      BERKSHIRE HATHAWAY INC            2019
# 6431    ALLEGHENY     15225                         NaN            2019
# 6430    ALLEGHENY     15225                         NaN            2019
# 12824   ALLEGHENY     15122           CLEAN HARBORS INC            2019
# 23863   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC            2019
#
#                   CHEM_NAME CARCINOGEN CLEAN_AIR ENVIRONMENTAL_MEDIUM
# 24591        ZINC COMPOUNDS          N         N            AIR STACK
# 7955       BARIUM COMPOUNDS          N         N            AIR STACK
# 4568                BENZENE          Y         Y              AIR FUG
# 4569                BENZENE          Y         Y            AIR STACK
# 22214              CHLORINE          N         Y              AIR FUG
# ...                     ...        ...       ...                  ...
# 6462               METHANOL          N         Y              AIR FUG
# 6431       MALEIC ANHYDRIDE          N         Y            AIR STACK
# 6430       MALEIC ANHYDRIDE          N         Y              AIR FUG
# 12824  BENZO(G,H,I)PERYLENE          N         Y              AIR FUG
# 23863     HYDROGEN FLUORIDE          N         Y            AIR STACK
#
# [14284 rows x 11 columns]

# %%
water.sort_values('REPORTING_YEAR')
# Out:
#                                     FACILITY_NAME          STREET_ADDRESS  \
# 13184    UNIVERSAL STAINLESS & ALLOY PRODUCTS INC            600 MAYER ST
# 2472                                 SHENANGO INC          200 NEVILLE RD
# 13526                       CHASE CORP-PITTSBURGH            128 FIRST ST
# 2499                                      IDL INC   535 OLD FRANKSTOWN RD
# 2502   USS MON VALLEY WORKS - EDGAR THOMSON PLANT  BRADDOCK AVE & 13TH ST
# ...                                           ...                     ...
# 5732                         PRESSURE CHEMICAL CO        3419 SMALLMAN ST
# 5780           USS MON VALLEY WORKS - IRVIN PLANT          CAMP HOLLOW RD
# 11329        PPG INDUSTRIESINC-SPRINGDALE COMPLEX           125 COLFAX ST
# 13414  USS MON VALLEY WORKS - EDGAR THOMSON PLANT  BRADDOCK AVE & 13TH ST
# 7509           BRISTOL METALS LLC - MUNHALL PLANT    1001 E WATERFRONT DR
#
#           CITY_NAME COUNTY_NAME  ZIP_CODE  \
# 13184   BRIDGEVILLE   ALLEGHENY     15017
# 2472     PITTSBURGH   ALLEGHENY     15225
# 13526    PITTSBURGH   ALLEGHENY     15238
# 2499     PITTSBURGH   ALLEGHENY     15239
# 2502       BRADDOCK   ALLEGHENY     15104
# ...             ...         ...       ...
# 5732     PITTSBURGH   ALLEGHENY     15201
# 5780   WEST MIFFLIN   ALLEGHENY     15122
# 11329    SPRINGDALE   ALLEGHENY     15144
# 13414      BRADDOCK   ALLEGHENY     15104
# 7509        MUNHALL   ALLEGHENY     15120
#
#                     STANDARDIZED_PARENT_COMPANY  REPORTING_YEAR  \
# 13184  UNIVERSAL STAINLESS & ALLOY PRODUCTS INC            2000
# 2472                              DTE ENERGY CO            2000
# 13526                                CHASE CORP            2000
# 2499                                        NaN            2000
# 2502                              US STEEL CORP            2000
# ...                                         ...             ...
# 5732                                        NaN            2019
# 5780                              US STEEL CORP            2019
# 11329                        PPG INDUSTRIES INC            2019
# 13414                             US STEEL CORP            2019
# 7509                              SYNALLOY CORP            2019
#
#                     CHEM_NAME CARCINOGEN CLEAN_AIR ENVIRONMENTAL_MEDIUM  \
# 13184        COPPER COMPOUNDS          N         N                WATER
# 2472   CRESOL (MIXED ISOMERS)          N         Y                WATER
# 13526     METHYL ETHYL KETONE          N         N                WATER
# 2499                  TOLUENE          N         Y                WATER
# 2502         NICKEL COMPOUNDS          Y         Y                WATER
# ...                       ...        ...       ...                  ...
# 5732          DICHLOROMETHANE          Y         Y                WATER
# 5780           ZINC COMPOUNDS          N         N                WATER
# 11329                 TOLUENE          N         Y                WATER
# 13414       MERCURY COMPOUNDS          N         Y                WATER
# 7509        HYDROGEN FLUORIDE          N         Y                WATER
#
#              STREAM_NAME
# 13184    CHARTIERS CREEK
# 2472                 NaN
# 13526                NaN
# 2499                 NaN
# 2502   MONONGAHELA RIVER
# ...                  ...
# 5732                 NaN
# 5780   MONONGAHELA RIVER
# 11329    ALLEGHENY RIVER
# 13414  MONONGAHELA RIVER
# 7509                 NaN
#
# [7348 rows x 12 columns]

# %%
land.sort_values('REPORTING_YEAR')
# Out:
#                                FACILITY_NAME          STREET_ADDRESS  \
# 44334                  RANBAR TECHNOLOGY INC  1114 WILLIAM FLINN HWY
# 38902   PPG INDUSTRIESINC-SPRINGDALE COMPLEX           125 COLFAX ST
# 38901   PPG INDUSTRIESINC-SPRINGDALE COMPLEX           125 COLFAX ST
# 46504  ATI FLAT ROLLED PRODUCTS HOLDINGS LLC            100 RIVER RD
# 46505  ATI FLAT ROLLED PRODUCTS HOLDINGS LLC            100 RIVER RD
# ...                                      ...                     ...
# 15321                    NEVILLE CHEMICAL CO         2800 NEVILLE RD
# 15322                    NEVILLE CHEMICAL CO         2800 NEVILLE RD
# 15323                    NEVILLE CHEMICAL CO         2800 NEVILLE RD
# 38703                     USS-CLAIRTON PLANT      400 STATE ST MS 71
# 38716                          BARBER SPRING      ONE MCCANDLESS AVE
#
#           CITY_NAME COUNTY_NAME  ZIP_CODE STANDARDIZED_PARENT_COMPANY  \
# 44334      GLENSHAW   ALLEGHENY     15116                         NaN
# 38902    SPRINGDALE   ALLEGHENY     15144          PPG INDUSTRIES INC
# 38901    SPRINGDALE   ALLEGHENY     15144          PPG INDUSTRIES INC
# 46504  BRACKENRIDGE   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC
# 46505  BRACKENRIDGE   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC
# ...             ...         ...       ...                         ...
# 15321    PITTSBURGH   ALLEGHENY     15225                         NaN
# 15322    PITTSBURGH   ALLEGHENY     15225                         NaN
# 15323    PITTSBURGH   ALLEGHENY     15225                         NaN
# 38703      CLAIRTON   ALLEGHENY     15025               US STEEL CORP
# 38716    PITTSBURGH   ALLEGHENY     15201                 WABTEC CORP
#
#        REPORTING_YEAR                CHEM_NAME CARCINOGEN CLEAN_AIR  \
# 44334            2000       PHTHALIC ANHYDRIDE          N         Y
# 38902            2000   N-METHYL-2-PYRROLIDONE          N         N
# 38901            2000   N-METHYL-2-PYRROLIDONE          N         N
# 46504            2000  ALUMINUM (FUME OR DUST)          N         N
# 46505            2000  ALUMINUM (FUME OR DUST)          N         N
# ...               ...                      ...        ...       ...
# 15321            2019                  TOLUENE          N         Y
# 15322            2019                  TOLUENE          N         Y
# 15323            2019                  TOLUENE          N         Y
# 38703            2019        DICYCLOPENTADIENE          N         N
# 38716            2019                MANGANESE          N         Y
#
#       ENVIRONMENTAL_MEDIUM
# 44334             SURF IMP
# 38902             OTH DISP
# 38901            LAND TREA
# 46504            LAND TREA
# 46505             OTH DISP
# ...                    ...
# 15321               RCRA C
# 15322            SI 5.5.3A
# 15323            SI 5.5.3B
# 38703               RCRA C
# 38716            SI 5.5.3A
#
# [41632 rows x 11 columns]

# %%
ug.sort_values('REPORTING_YEAR')
# Out:
#                                           FACILITY_NAME  \
# 26388             ATI FLAT ROLLED PRODUCTS HOLDINGS LLC
# 8553   EXXONMOBIL LUBRICANTS & PETROLEUM SPECIALTIES CO
# 4916            EXXONMOBIL CORP NEVILLE ISLAND TERMINAL
# 4917            EXXONMOBIL CORP NEVILLE ISLAND TERMINAL
# 23859          UNIVAR SOLUTIONS USA INC - BUNOLA BRANCH
# ...                                                 ...
# 6974                                  THE LUBRIZOL CORP
# 6939                            INEOS COMPOSITES US LLC
# 6938                            INEOS COMPOSITES US LLC
# 13764           SAFETY-KLEEN SYSTEMS WEST MIFFLIN (WMP)
# 25609             ATI FLAT ROLLED PRODUCTS HOLDINGS LLC
#
#                                           STREET_ADDRESS     CITY_NAME  \
# 26388                                       100 RIVER RD  BRACKENRIDGE
# 8553                  1031 MIDDLESEX ST BAKERSTOWN PLANT    BAKERSTOWN
# 4916                                     2760 NEVILLE RD    PITTSBURGH
# 4917                                     2760 NEVILLE RD    PITTSBURGH
# 23859                                328 BUNOLA RIVER RD        BUNOLA
# ...                                                  ...           ...
# 6974   100 LEETSDALE INDUSTRIAL DR - BUILDINGS 72, 76...     LEETSDALE
# 6939                                     2650 NEVILLE RD    PITTSBURGH
# 6938                                     2650 NEVILLE RD    PITTSBURGH
# 13764                                       650 NOBLE DR  WEST MIFFLIN
# 25609                                       100 RIVER RD  BRACKENRIDGE
#
#       COUNTY_NAME  ZIP_CODE STANDARDIZED_PARENT_COMPANY  REPORTING_YEAR  \
# 26388   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC            2000
# 8553    ALLEGHENY     15007                         NaN            2000
# 4916    ALLEGHENY     15225                         NaN            2000
# 4917    ALLEGHENY     15225                         NaN            2000
# 23859   ALLEGHENY     15020                         NaN            2000
# ...           ...       ...                         ...             ...
# 6974    ALLEGHENY     15056      BERKSHIRE HATHAWAY INC            2019
# 6939    ALLEGHENY     15225                         NaN            2019
# 6938    ALLEGHENY     15225                         NaN            2019
# 13764   ALLEGHENY     15122           CLEAN HARBORS INC            2019
# 25609   ALLEGHENY     15014  ALLEGHENY TECHNOLOGIES INC            2019
#
#                   CHEM_NAME CARCINOGEN CLEAN_AIR ENVIRONMENTAL_MEDIUM
# 26388        ZINC COMPOUNDS          N         N            UNINJ IIV
# 8553       BARIUM COMPOUNDS          N         N            UNINJ IIV
# 4916                BENZENE          Y         Y              UNINJ I
# 4917                BENZENE          Y         Y            UNINJ IIV
# 23859              CHLORINE          N         Y              UNINJ I
# ...                     ...        ...       ...                  ...
# 6974               METHANOL          N         Y              UNINJ I
# 6939       MALEIC ANHYDRIDE          N         Y            UNINJ IIV
# 6938       MALEIC ANHYDRIDE          N         Y              UNINJ I
# 13764  BENZO(G,H,I)PERYLENE          N         Y              UNINJ I
# 25609     HYDROGEN FLUORIDE          N         Y            UNINJ IIV
#
# [14284 rows x 11 columns]

# %%
chemical = {}
count = 0
for i in range(len(air)):
    count += 1
    chemical.loc['count'] = []
