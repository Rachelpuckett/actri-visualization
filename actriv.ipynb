# %% [markdown]
# # actri-visualization

# %%
import ssl
import numpy as np
import matplotlib
import pandas as pd

# %%
##pd settings
pd.set_option('display.max_columns', 100)
##opening databases
land = pd.read_csv("tri_land.csv")
air = pd.read_csv("tri_air.csv")
ug = pd.read_csv("tri_underground1.csv")
water = pd.read_csv("tri_water.csv")

##displaying first 5 rows of each database
land.head(5)
#air.head(5)
#ug.head(5)
#water.head(5)
# Out:
# /usr/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (13,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /usr/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    TRI_FACILITY_ID   DOC_CTRL_NUM                   FACILITY_NAME  \
# 0  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
# 1  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
# 2  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
# 3  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
# 4  15025RSTCH400ST  1388025294164  KOPPERS INC CLAIRTON TAR PLANT
#
#    STREET_ADDRESS CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE STATE_ABBR  \
# 0  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 1  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 2  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 3  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
# 4  300 N STATE ST  CLAIRTON   ALLEGHENY                   42003         PA
#
#    ZIP_CODE  REGION  FAC_CLOSED_IND ASGN_FEDERAL_IND ASGN_AGENCY  \
# 0     15025       3               0                C         NaN
# 1     15025       3               0                C         NaN
# 2     15025       3               0                C         NaN
# 3     15025       3               0                C         NaN
# 4     15025       3               0                C         NaN
#
#   PARENT_CO_DB_NUM PARENT_CO_NAME STANDARDIZED_PARENT_COMPANY  \
# 0        196991582    KOPPERS INC                 KOPPERS INC
# 1        196991582    KOPPERS INC                 KOPPERS INC
# 2        196991582    KOPPERS INC                 KOPPERS INC
# 3        196991582    KOPPERS INC                 KOPPERS INC
# 4        196991582    KOPPERS INC                 KOPPERS INC
#
#    EPA_REGISTRY_ID  TRADE_SECRET_IND  REPORTING_YEAR ELEMENTAL_METAL_INCLUDED  \
# 0     1.100003e+11                 0            1988                 106-44-5
# 1     1.100003e+11                 0            1988                 106-44-5
# 2     1.100003e+11                 0            1988                 106-44-5
# 3     1.100003e+11                 0            1988                 106-44-5
# 4     1.100003e+11                 0            1988                 106-44-5
#
#   CAS_NUM CHEM_NAME LIST_3350 CARCINOGEN CLEAN_AIR PRIMARY_SIC_CODE SIC_CODES  \
# 0     NaN  P-CRESOL         N          N         Y             2865      2865
# 1     NaN  P-CRESOL         N          N         Y             2865      2865
# 2     NaN  P-CRESOL         N          N         Y             2865      2865
# 3     NaN  P-CRESOL         N          N         Y             2865      2865
# 4     NaN  P-CRESOL         N          N         Y             2865      2865
#
#    PRIMARY_NAICS_CODE  NAICS_CODES  INDUSTRY_CODE ENVIRONMENTAL_MEDIUM  \
# 0              325192     325192.0            325            LAND TREA
# 1              325192     325192.0            325            LANDF8795
# 2              325192     325192.0            325             OTH DISP
# 3              325192     325192.0            325            OTH LANDF
# 4              325192     325192.0            325               RCRA C
#
#   RELEASE_RANGE_CODE  TOTAL_RELEASE  REL_EST_AMT  RELEASE_NA  \
# 0                NaN            NaN          0.0           1
# 1                NaN            NaN          0.0           1
# 2                NaN            NaN          0.0           1
# 3                NaN            NaN          0.0           0
# 4                NaN            NaN          0.0           0
#
#   RELEASE_BASIS_EST_CODE   SRS_ID
# 0                    NaN  23606.0
# 1                    NaN  23606.0
# 2                    NaN  23606.0
# 3                    NaN  23606.0
# 4                    NaN  23606.0

# %%
# Let's try cleaning this up a bit. 
#land.drop(columns=['TRI_FACILITY_ID', 'DOC_CTRL_NUM', 'STATE_COUNTY_FIPS_CODE', 'STATE_ABBR', 'REGION', 'PRIMARY_NAICS_CODE', 'NAICS_CODES', "INDUSTRY_CODE"])
land.drop(columns=[land.columns[0], land.columns[1], land.columns[6], land.columns[7], land.columns[9]
                  , land.columns[10], land.columns[11], land.columns[12], land.columns[13]
                  , land.columns[14], land.columns[16], land.columns[17], land.columns[18], land.columns[19]])
# Out:
#                         FACILITY_NAME          STREET_ADDRESS   CITY_NAME  \
# 0      KOPPERS INC CLAIRTON TAR PLANT          300 N STATE ST    CLAIRTON
# 1      KOPPERS INC CLAIRTON TAR PLANT          300 N STATE ST    CLAIRTON
# 2      KOPPERS INC CLAIRTON TAR PLANT          300 N STATE ST    CLAIRTON
# 3      KOPPERS INC CLAIRTON TAR PLANT          300 N STATE ST    CLAIRTON
# 4      KOPPERS INC CLAIRTON TAR PLANT          300 N STATE ST    CLAIRTON
# ...                               ...                     ...         ...
# 70266            CHESWICK POWER PLANT  PITTSBURGH & PORTER ST  SPRINGDALE
# 70267            CHESWICK POWER PLANT  PITTSBURGH & PORTER ST  SPRINGDALE
# 70268            CHESWICK POWER PLANT  PITTSBURGH & PORTER ST  SPRINGDALE
# 70269            CHESWICK POWER PLANT  PITTSBURGH & PORTER ST  SPRINGDALE
# 70270            CHESWICK POWER PLANT  PITTSBURGH & PORTER ST  SPRINGDALE
#
#       COUNTY_NAME  ZIP_CODE STANDARDIZED_PARENT_COMPANY CAS_NUM  \
# 0       ALLEGHENY     15025                 KOPPERS INC     NaN
# 1       ALLEGHENY     15025                 KOPPERS INC     NaN
# 2       ALLEGHENY     15025                 KOPPERS INC     NaN
# 3       ALLEGHENY     15025                 KOPPERS INC     NaN
# 4       ALLEGHENY     15025                 KOPPERS INC     NaN
# ...           ...       ...                         ...     ...
# 70266   ALLEGHENY     15144          GENON HOLDINGS INC     NaN
# 70267   ALLEGHENY     15144          GENON HOLDINGS INC     NaN
# 70268   ALLEGHENY     15144          GENON HOLDINGS INC     NaN
# 70269   ALLEGHENY     15144          GENON HOLDINGS INC     NaN
# 70270   ALLEGHENY     15144          GENON HOLDINGS INC     NaN
#
#                CHEM_NAME LIST_3350 CARCINOGEN  ... PRIMARY_NAICS_CODE  \
# 0               P-CRESOL         N          N  ...             325192
# 1               P-CRESOL         N          N  ...             325192
# 2               P-CRESOL         N          N  ...             325192
# 3               P-CRESOL         N          N  ...             325192
# 4               P-CRESOL         N          N  ...             325192
# ...                  ...       ...        ...  ...                ...
# 70266  ARSENIC COMPOUNDS         N          N  ...             221112
# 70267  ARSENIC COMPOUNDS         N          N  ...             221112
# 70268  ARSENIC COMPOUNDS         N          N  ...             221112
# 70269  ARSENIC COMPOUNDS         N          N  ...             221112
# 70270  ARSENIC COMPOUNDS         N          N  ...             221112
#
#       NAICS_CODES INDUSTRY_CODE  ENVIRONMENTAL_MEDIUM  RELEASE_RANGE_CODE  \
# 0        325192.0           325             LAND TREA                 NaN
# 1        325192.0           325             LANDF8795                 NaN
# 2        325192.0           325              OTH DISP                 NaN
# 3        325192.0           325             OTH LANDF                 NaN
# 4        325192.0           325                RCRA C                 NaN
# ...           ...           ...                   ...                 ...
# 70266    221112.0          2211              OTH DISP                 NaN
# 70267    221112.0          2211             OTH LANDF                 NaN
# 70268    221112.0          2211                RCRA C                 NaN
# 70269    221112.0          2211             SI 5.5.3A                 NaN
# 70270    221112.0          2211             SI 5.5.3B                 NaN
#
#        TOTAL_RELEASE REL_EST_AMT RELEASE_NA  RELEASE_BASIS_EST_CODE    SRS_ID
# 0                NaN         0.0          1                     NaN   23606.0
# 1                NaN         0.0          1                     NaN   23606.0
# 2                NaN         0.0          1                     NaN   23606.0
# 3                NaN         0.0          0                     NaN   23606.0
# 4                NaN         0.0          0                     NaN   23606.0
# ...              ...         ...        ...                     ...       ...
# 70266            NaN         0.0          1                     NaN  649418.0
# 70267            NaN         0.0          1                     NaN  649418.0
# 70268            NaN         0.0          1                     NaN  649418.0
# 70269            NaN         0.0          1                     NaN  649418.0
# 70270            NaN         0.0          1                     NaN  649418.0
#
# [70271 rows x 23 columns]
