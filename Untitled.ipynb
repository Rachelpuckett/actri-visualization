# %%
import ssl
import numpy as np
import matplotlib
import pandas as pd

# %%
##open air database
air = pd.read_csv("tri_air.csv")

##drops columns that we don't need
air = air.drop(columns=['TRI_FACILITY_ID','DOC_CTRL_NUM', 'STATE_COUNTY_FIPS_CODE', 'STATE_ABBR', 'REGION'
                   , 'FAC_CLOSED_IND', 'ASGN_FEDERAL_IND', 'ASGN_AGENCY', 'PARENT_CO_DB_NUM'
                   , 'PARENT_CO_NAME', 'EPA_REGISTRY_ID', 'TRADE_SECRET_IND', 'ELEMENTAL_METAL_INCLUDED'
                   , 'CAS_NUM', 'LIST_3350', 'PRIMARY_SIC_CODE', 'SIC_CODES', 'PRIMARY_NAICS_CODE'
                   , 'NAICS_CODES', 'INDUSTRY_CODE', 'RELEASE_RANGE_CODE', 'TOTAL_RELEASE'
                   , 'REL_EST_AMT', 'RELEASE_NA', 'RELEASE_BASIS_EST_CODE', 'SRS_ID'])

air.drop(air[air['REPORTING_YEAR'] < 2000].index, inplace = True)

# %%
air_grouped = air.groupby('CHEM_NAME').count()
air_grouped.head(10)
air_grouped.sort_values('FACILITY_NAME')
# Out:
#                               FACILITY_NAME  STREET_ADDRESS  CITY_NAME  \
# CHEM_NAME
# SILVER and SILVER COMPOUNDS               2               2          2
# BENZOYL PEROXIDE                          2               2          2
# DIETHANOLAMINE                            2               2          2
# PHOSPHORUS (YELLOW OR WHITE)              2               2          2
# 2,4-DINITROTOLUENE                        2               2          2
# ...                                     ...             ...        ...
# 1,2,4-TRIMETHYLBENZENE                  444             444        444
# LEAD                                    550             550        550
# TOLUENE                                 672             672        672
# XYLENE (MIXED ISOMERS)                  752             752        752
# LEAD COMPOUNDS                          808             808        808
#
#                               COUNTY_NAME  ZIP_CODE  \
# CHEM_NAME
# SILVER and SILVER COMPOUNDS             2         2
# BENZOYL PEROXIDE                        2         2
# DIETHANOLAMINE                          2         2
# PHOSPHORUS (YELLOW OR WHITE)            2         2
# 2,4-DINITROTOLUENE                      2         2
# ...                                   ...       ...
# 1,2,4-TRIMETHYLBENZENE                444       444
# LEAD                                  550       550
# TOLUENE                               672       672
# XYLENE (MIXED ISOMERS)                752       752
# LEAD COMPOUNDS                        808       808
#
#                               STANDARDIZED_PARENT_COMPANY  REPORTING_YEAR  \
# CHEM_NAME
# SILVER and SILVER COMPOUNDS                             2               2
# BENZOYL PEROXIDE                                        2               2
# DIETHANOLAMINE                                          2               2
# PHOSPHORUS (YELLOW OR WHITE)                            2               2
# 2,4-DINITROTOLUENE                                      2               2
# ...                                                   ...             ...
# 1,2,4-TRIMETHYLBENZENE                                300             444
# LEAD                                                  362             550
# TOLUENE                                               418             672
# XYLENE (MIXED ISOMERS)                                524             752
# LEAD COMPOUNDS                                        644             808
#
#                               CARCINOGEN  CLEAN_AIR  ENVIRONMENTAL_MEDIUM
# CHEM_NAME
# SILVER and SILVER COMPOUNDS            2          2                     2
# BENZOYL PEROXIDE                       2          2                     2
# DIETHANOLAMINE                         2          2                     2
# PHOSPHORUS (YELLOW OR WHITE)           2          2                     2
# 2,4-DINITROTOLUENE                     2          2                     2
# ...                                  ...        ...                   ...
# 1,2,4-TRIMETHYLBENZENE               444        444                   444
# LEAD                                 550        550                   550
# TOLUENE                              672        672                   672
# XYLENE (MIXED ISOMERS)               752        752                   752
# LEAD COMPOUNDS                       808        808                   808
#
# [131 rows x 10 columns]
